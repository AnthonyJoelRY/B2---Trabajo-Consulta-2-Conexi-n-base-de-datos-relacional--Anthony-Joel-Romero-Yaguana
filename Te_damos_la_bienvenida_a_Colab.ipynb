# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyJoelRY/B2---Trabajo-Consulta-2-Conexi-n-base-de-datos-relacional--Anthony-Joel-Romero-Yaguana/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESTADISTICA Y PROBABILIDAD : Actividad en Clases

# %% [markdown]
# Leandro Saquisari y Anthony Romero

# %%
# ===============================================
# 📊 Análisis de la variable Global_Sales
# ===============================================
# Este programa:
# 1. Permite seleccionar un archivo CSV con un picker
# 2. Carga los datos en un DataFrame
# 3. Muestra un histograma y un diagrama de caja
# ===============================================

import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# --- 1️⃣ Subir archivo CSV ---
print("📂 Selecciona tu archivo CSV con los datos (por ejemplo: vgsales.csv)")
uploaded = files.upload()

# Obtener el nombre del archivo subido
file_name = list(uploaded.keys())[0]

# --- 2️⃣ Cargar el archivo en un DataFrame ---
df = pd.read_csv(file_name)

# Mostrar las primeras filas
print("\n✅ Archivo cargado correctamente:")
print(df.head())

# --- 3️⃣ Verificar existencia de la variable Global_Sales ---
if 'Global_Sales' not in df.columns:
    raise ValueError("❌ La columna 'Global_Sales' no se encuentra en el archivo CSV.")

# Convertir a numérico en caso de que tenga valores no numéricos
df['Global_Sales'] = pd.to_numeric(df['Global_Sales'], errors='coerce')

# --- 4️⃣ Mostrar estadísticas básicas ---
print("\n📈 Estadísticas descriptivas de Global_Sales:")
print(df['Global_Sales'].describe())

# --- 5️⃣ Graficar histograma ---
plt.figure(figsize=(8, 5))
plt.hist(df['Global_Sales'].dropna(), bins=20, edgecolor='black')
plt.title('Histograma de Global_Sales')
plt.xlabel('Ventas Globales (en millones)')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# --- 6️⃣ Graficar diagrama de caja ---
plt.figure(figsize=(5, 7))
plt.boxplot(df['Global_Sales'].dropna(), vert=True)
plt.title('Diagrama de Caja de Global_Sales')
plt.ylabel('Ventas Globales (en millones)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# 📂 Selecciona tu archivo CSV con los datos (por ejemplo: vgsales.csv)
#      <input type="file" id="files-5e87d3c9-5645-4b92-91e6-ced798069acc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e87d3c9-5645-4b92-91e6-ced798069acc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# === 5️⃣ Graficar histograma con curva normal, desviaciones estándar, media, mediana y moda ===
plt.figure(figsize=(9,6))
count, bins, ignored = plt.hist(df["Edad"], bins=12, density=True, alpha=0.6, color='skyblue', edgecolor='black')

# Crear curva normal teórica
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, media, desviacion)
plt.plot(x, p, 'r', linewidth=2, label='Curva Normal')

# Líneas verticales principales
plt.axvline(media, color='green', linestyle='--', linewidth=2, label=f"Media = {media:.2f}")
plt.axvline(mediana, color='purple', linestyle='--', linewidth=2, label=f"Mediana = {mediana:.2f}")
plt.axvline(moda, color='blue', linestyle='--', linewidth=2, label=f"Moda = {moda:.2f}")

# Líneas de desviaciones estándar
plt.axvline(media + desviacion, color='orange', linestyle='--', linewidth=1.5, label=f"+1σ = {media + desviacion:.2f}")
plt.axvline(media - desviacion, color='orange', linestyle='--', linewidth=1.5, label=f"-1σ = {media - desviacion:.2f}")
plt.axvline(media + 2*desviacion, color='red', linestyle=':', linewidth=1.2, label=f"+2σ = {media + 2*desviacion:.2f}")
plt.axvline(media - 2*desviacion, color='red', linestyle=':', linewidth=1.2, label=f"-2σ = {media - 2*desviacion:.2f}")

# Personalización del gráfico
plt.title("Distribución de Edades con Curva Normal, Media, Mediana, Moda y Desviaciones Estándar")
plt.xlabel("Edad")
plt.ylabel("Densidad de frecuencia")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
